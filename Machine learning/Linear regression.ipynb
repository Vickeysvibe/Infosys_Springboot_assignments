# %% [markdown]
# Machine learning

# %%
#1.Consider the column, ‘RM’, as predictor, and ‘MEDV’ as the target variable

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

data=pd.read_csv('dataset/boston_housing.csv')
x=data[['RM']]
y=data['MEDV']


# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Calculate the mean squared error and the coefficient of determination (R^2)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 46.144775347317264
# R^2 Score: 0.3707569232254778

# %%
#2.Visualize the association between the predictor and the target using scatter plot.
import matplotlib.pyplot as plt
plt.scatter(X_test, y_test, color='black', label='Actual data')
plt.plot(X_test, y_pred, color='blue', linewidth=3, label='Predicted line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression Example')
plt.legend()
plt.show()

# %%
#3.Split the data into train and test datasets, in the ratio of 67:33.
X1_train, X1_test, y1_train, y1_test = train_test_split(x, y, test_size=0.33, random_state=42)
print(X1_train)
# Out:
#         RM
# 478  6.185
# 26   5.813
# 7    6.172
# 492  5.983
# 108  6.474
# ..     ...
# 106  5.836
# 270  5.856
# 348  6.635
# 435  6.629
# 102  6.405
#
# [339 rows x 1 columns]

# %%
#4.Build a Linear Regression model using training dataset, to predict the target variable.

value=model.predict([[6.185]])
print(value)
# Out:
# [21.5729253]
# C:\Users\vicke\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#5. Observe the coefficient and intercept values for the model.
#6. Evaluate the model using mean squared error values and R-squared values on the training and the testing datasets.
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

coefficient = model.coef_[0]
intercept = model.intercept_

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
print(f"Coefficient: {coefficient}")
print(f"Intercept: {intercept}")
# Out:
# Mean Squared Error: 46.144775347317264
# R^2 Score: 0.3707569232254778
# Coefficient: 9.348301406497722
# Intercept: -36.24631889813792
